# %%
a=5
b=10
a=5
b=10
c=a*b

print(c)
# Out:
# 50

# %%
no=10
no=50
print(no1>no2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-262dc7224c45> in <cell line: 0>()
#       1 no=10
#       2 no=50
# ----> 3 print(no1>no2)
#
# NameError: name 'no1' is not defined
